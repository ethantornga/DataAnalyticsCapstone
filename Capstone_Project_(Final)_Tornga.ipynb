# %%
# !git clone https://github.com/ethantornga/DataAnalyticsCapstone.git
# Out:
# Cloning into 'DataAnalyticsCapstone'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 63 (delta 23), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (63/63), 12.94 MiB | 9.12 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import itertools as it
import collections as co
import time

from sklearn import datasets, metrics, neighbors, naive_bayes, linear_model, dummy, pipeline, feature_selection as ftr_sel, model_selection as skms, preprocessing as skpre
from sklearn.naive_bayes import GaussianNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import tree, svm, ensemble as ens
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, cross_val_predict, GridSearchCV, ParameterGrid
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.compose import ColumnTransformer

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

from scipy.stats import zscore
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#1. Load the Data

data = "/content/DataAnalyticsCapstone/mba_decision_new.csv"
df = pd.read_csv(data)

print(df.head())
# Out:
#    Person ID  Age  Gender Undergraduate Major  Undergraduate GPA  \
# 0          1   27    Male                Arts               3.18
# 1          2   24    Male                Arts               3.03
# 2          3   33  Female            Business               3.66
# 3          4   31    Male         Engineering               2.46
# 4          5   28  Female            Business               2.75
#
#    Years of Work Experience Current Job Title  Annual Salary (Before MBA)  \
# 0                         8      Entrepreneur                       90624
# 1                         4           Analyst                       53576
# 2                         9          Engineer                       79796
# 3                         1           Manager                      105956
# 4                         9      Entrepreneur                       96132
#
#   Has Management Experience  GRE/GMAT Score  Undergrad University Ranking  \
# 0                        No             688                           185
# 1                       Yes             791                           405
# 2                        No             430                           107
# 3                        No             356                           257
# 4                        No             472                           338
#
#   MBA Funding Source Desired Post-MBA Role  Expected Post-MBA Salary  \
# 0               Loan       Finance Manager                    156165
# 1               Loan       Startup Founder                    165612
# 2        Scholarship            Consultant                    122248
# 3               Loan            Consultant                    123797
# 4               Loan            Consultant                    197509
#
#   Location Preference (Post-MBA)     Reason for MBA Online vs. On-Campus MBA  \
# 0                  International   Entrepreneurship                On-Campus
# 1                  International      Career Growth                   Online
# 2                       Domestic  Skill Enhancement                   Online
# 3                  International   Entrepreneurship                On-Campus
# 4                       Domestic  Skill Enhancement                   Online
#
#   Decided to Pursue MBA?  Salary Difference  Percent of Life Worked
# 0                    Yes              65541                0.296296
# 1                     No             112036                0.166667
# 2                     No              42452                0.272727
# 3                     No              17841                0.032258
# 4                    Yes             101377                0.321429

# %%
#2. Data Cleaning/Preprocessing

#Missing Values (None)
missing_values = df.isnull().sum()
print(missing_values)

#Detecting Outliers w/ z-score (None)
z_scores = df.select_dtypes(include=['float64', 'int64']).apply(zscore)

outliers = df[(z_scores > 3).any(axis=1)]
print("\nOutliers using Z-Score:\n", outliers)

#Encoding (Dummy Variables)
df['Gender'] = df['Gender'].map({'Female': 0, 'Male': 1, 'Other': 2})
df['Undergraduate Major'] = df['Undergraduate Major'].map({'Business': 1, 'Economics': 1, 'Arts': 0,  'Science': 0, 'Engineering': 0})
df['Current Job Title'] = df['Current Job Title'].map({'Manager': 1, 'Entrepreneur': 0, 'Analyst': 0, 'Engineer': 0, 'Consultant': 0, })
df['Has Management Experience'] = df['Has Management Experience'].map({'No': 0, 'Yes': 1})
df['MBA Funding Source'] = df['MBA Funding Source'].map({'Scholarship': 1, 'Employer': 1, 'Loan': 0, 'Self-funded': 0})
df['Desired Post-MBA Role'] = df['Desired Post-MBA Role'].map({'Finance Manager': 1, 'Startup Founder': 1, 'Executive': 1, 'Marketing Director': 1, 'Consultant': 0})
df['Online vs. On-Campus MBA'] = df['Online vs. On-Campus MBA'].map({'Online': 0, 'On-Campus': 1})
df['Location Preference (Post-MBA)'] = df['Location Preference (Post-MBA)'].map({'Domestic': 0, 'International': 1})
df['Reason for MBA'] = df['Reason for MBA'].map({'Career Growth': 1, 'Entrepreneurship': 1, 'Networking': 0, 'Skill Enhancement': 0})
df['Decided to Pursue MBA?'] = df['Decided to Pursue MBA?'].map({'No': 0, 'Yes': 1})

print(df.head())
# Out:
# Person ID                         0
# Age                               0
# Gender                            0
# Undergraduate Major               0
# Undergraduate GPA                 0
# Years of Work Experience          0
# Current Job Title                 0
# Annual Salary (Before MBA)        0
# Has Management Experience         0
# GRE/GMAT Score                    0
# Undergrad University Ranking      0
# MBA Funding Source                0
# Desired Post-MBA Role             0
# Expected Post-MBA Salary          0
# Location Preference (Post-MBA)    0
# Reason for MBA                    0
# Online vs. On-Campus MBA          0
# Decided to Pursue MBA?            0
# Salary Difference                 0
# Percent of Life Worked            0
# dtype: int64
#
# Outliers using Z-Score:
#  Empty DataFrame
# Columns: [Person ID, Age, Gender, Undergraduate Major, Undergraduate GPA, Years of Work Experience, Current Job Title, Annual Salary (Before MBA), Has Management Experience, GRE/GMAT Score, Undergrad University Ranking, MBA Funding Source, Desired Post-MBA Role, Expected Post-MBA Salary, Location Preference (Post-MBA), Reason for MBA, Online vs. On-Campus MBA, Decided to Pursue MBA?, Salary Difference, Percent of Life Worked]
# Index: []
#    Person ID  Age  Gender  Undergraduate Major  Undergraduate GPA  \
# 0          1   27       1                    0               3.18
# 1          2   24       1                    0               3.03
# 2          3   33       0                    1               3.66
# 3          4   31       1                    0               2.46
# 4          5   28       0                    1               2.75
#
#    Years of Work Experience  Current Job Title  Annual Salary (Before MBA)  \
# 0                         8                  0                       90624
# 1                         4                  0                       53576
# 2                         9                  0                       79796
# 3                         1                  1                      105956
# 4                         9                  0                       96132
#
#    Has Management Experience  GRE/GMAT Score  Undergrad University Ranking  \
# 0                          0             688                           185
# 1                          1             791                           405
# 2                          0             430                           107
# 3                          0             356                           257
# 4                          0             472                           338
#
#    MBA Funding Source  Desired Post-MBA Role  Expected Post-MBA Salary  \
# 0                   0                      1                    156165
# 1                   0                      1                    165612
# 2                   1                      0                    122248
# 3                   0                      0                    123797
# 4                   0                      0                    197509
#
#    Location Preference (Post-MBA)  Reason for MBA  Online vs. On-Campus MBA  \
# 0                               1               1                         1
# 1                               1               1                         0
# 2                               0               0                         0
# 3                               1               1                         1
# 4                               0               0                         0
#
#    Decided to Pursue MBA?  Salary Difference  Percent of Life Worked
# 0                       1              65541                0.296296
# 1                       0             112036                0.166667
# 2                       0              42452                0.272727
# 3                       0              17841                0.032258
# 4                       1             101377                0.321429

# %%
# Pairplot of Variables
sns.pairplot(df[['Age', 'Undergraduate GPA', 'Salary Difference', 'Percent of Life Worked', 'Decided to Pursue MBA?']],
             height=2, hue='Decided to Pursue MBA?', plot_kws={'alpha':.2});

# %%
# Brief information on dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person ID                       10000 non-null  int64
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  int64
#  3   Undergraduate Major             10000 non-null  int64
#  4   Undergraduate GPA               10000 non-null  float64
#  5   Years of Work Experience        10000 non-null  int64
#  6   Current Job Title               10000 non-null  int64
#  7   Annual Salary (Before MBA)      10000 non-null  int64
#  8   Has Management Experience       10000 non-null  int64
#  9   GRE/GMAT Score                  10000 non-null  int64
#  10  Undergrad University Ranking    10000 non-null  int64
#  11  MBA Funding Source              10000 non-null  int64
#  12  Desired Post-MBA Role           10000 non-null  int64
#  13  Expected Post-MBA Salary        10000 non-null  int64
#  14  Location Preference (Post-MBA)  10000 non-null  int64
#  15  Reason for MBA                  10000 non-null  int64
#  16  Online vs. On-Campus MBA        10000 non-null  int64
#  17  Decided to Pursue MBA?          10000 non-null  int64
#  18  Salary Difference               10000 non-null  int64
#  19  Percent of Life Worked          10000 non-null  float64
# dtypes: float64(2), int64(18)
# memory usage: 1.5 MB
# None

# %%
# Decision Target Class Chart
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Decided to Pursue MBA?', palette='viridis')
plt.title('Class Distribution: MBA Admission Decision')
plt.xlabel('Decision')
plt.ylabel('Count')
plt.show()


#Categorical Feature vs. Target
categorical_col = 'Years of Work Experience' if 'Years of Work Experience' in df.columns else df.select_dtypes(include='object').columns[1]

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x=categorical_col, hue='Decided to Pursue MBA?', palette='viridis')
plt.title(f'{categorical_col} vs. MBA Decision')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-7-536a6823dece>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Decided to Pursue MBA?', palette='viridis')

# %%
#Creating training and testing splits in the data
(data_train_ftrs, data_test_ftrs,
data_train_tgt, data_test_tgt) = skms.train_test_split(df.drop('Decided to Pursue MBA?', axis=1),
                                                      df['Decided to Pursue MBA?'],
                                                      test_size=.30,
                                                      random_state=42)
#Shape of train/test features
print("Train features shape:", data_train_ftrs.shape)
print("Test features shape:", data_test_ftrs.shape)
# Out:
# Train features shape: (7000, 19)
# Test features shape: (3000, 19)

# %%
# DataFrame Correlation
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                                 Person ID       Age    Gender  \
# Person ID                        1.000000  0.006182 -0.000478
# Age                              0.006182  1.000000 -0.001644
# Gender                          -0.000478 -0.001644  1.000000
# Undergraduate Major              0.003263  0.007988  0.012496
# Undergraduate GPA                0.004599  0.014800  0.005598
# Years of Work Experience         0.002018 -0.000798 -0.005432
# Current Job Title                0.002389  0.002010  0.012994
# Annual Salary (Before MBA)       0.001637  0.011386 -0.012550
# Has Management Experience       -0.000675  0.005230 -0.006506
# GRE/GMAT Score                   0.021121  0.002036  0.003192
# Undergrad University Ranking     0.006243 -0.003281 -0.015647
# MBA Funding Source               0.008507 -0.005496 -0.008636
# Desired Post-MBA Role            0.007743 -0.001699  0.002167
# Expected Post-MBA Salary         0.002500  0.016200 -0.003292
# Location Preference (Post-MBA)  -0.008117  0.008160  0.001608
# Reason for MBA                  -0.002929 -0.002497  0.011413
# Online vs. On-Campus MBA         0.007276  0.015975  0.000172
# Decided to Pursue MBA?           0.001799  0.000614 -0.001175
# Salary Difference                0.001241  0.007617  0.003999
# Percent of Life Worked          -0.000807 -0.226782 -0.005961
#
#                                 Undergraduate Major  Undergraduate GPA  \
# Person ID                                  0.003263           0.004599
# Age                                        0.007988           0.014800
# Gender                                     0.012496           0.005598
# Undergraduate Major                        1.000000           0.002596
# Undergraduate GPA                          0.002596           1.000000
# Years of Work Experience                   0.001714          -0.010385
# Current Job Title                         -0.010108           0.013929
# Annual Salary (Before MBA)                -0.011453           0.002331
# Has Management Experience                  0.006839          -0.002126
# GRE/GMAT Score                             0.004822           0.013235
# Undergrad University Ranking               0.009238           0.002768
# MBA Funding Source                         0.009498          -0.005363
# Desired Post-MBA Role                      0.004580           0.009183
# Expected Post-MBA Salary                   0.007340          -0.000869
# Location Preference (Post-MBA)             0.004718          -0.002364
# Reason for MBA                             0.006429           0.000429
# Online vs. On-Campus MBA                   0.008558           0.001063
# Decided to Pursue MBA?                     0.000688          -0.008400
# Salary Difference                          0.012453          -0.002003
# Percent of Life Worked                    -0.000266          -0.013489
#
#                                 Years of Work Experience  Current Job Title  \
# Person ID                                       0.002018           0.002389
# Age                                            -0.000798           0.002010
# Gender                                         -0.005432           0.012994
# Undergraduate Major                             0.001714          -0.010108
# Undergraduate GPA                              -0.010385           0.013929
# Years of Work Experience                        1.000000          -0.016958
# Current Job Title                              -0.016958           1.000000
# Annual Salary (Before MBA)                     -0.022053          -0.000844
# Has Management Experience                      -0.013501          -0.006897
# GRE/GMAT Score                                  0.015480          -0.006611
# Undergrad University Ranking                    0.005455          -0.007176
# MBA Funding Source                             -0.002608          -0.002352
# Desired Post-MBA Role                           0.000922          -0.004511
# Expected Post-MBA Salary                       -0.002337          -0.018362
# Location Preference (Post-MBA)                 -0.007255           0.012410
# Reason for MBA                                 -0.013702           0.016909
# Online vs. On-Campus MBA                       -0.006023           0.022142
# Decided to Pursue MBA?                         -0.005571          -0.005370
# Salary Difference                               0.009962          -0.015170
# Percent of Life Worked                          0.962833          -0.018081
#
#                                 Annual Salary (Before MBA)  \
# Person ID                                         0.001637
# Age                                               0.011386
# Gender                                           -0.012550
# Undergraduate Major                              -0.011453
# Undergraduate GPA                                 0.002331
# Years of Work Experience                         -0.022053
# Current Job Title                                -0.000844
# Annual Salary (Before MBA)                        1.000000
# Has Management Experience                        -0.010309
# GRE/GMAT Score                                   -0.005471
# Undergrad University Ranking                     -0.000487
# MBA Funding Source                                0.011984
# Desired Post-MBA Role                            -0.013814
# Expected Post-MBA Salary                          0.019473
# Location Preference (Post-MBA)                   -0.010305
# Reason for MBA                                    0.017700
# Online vs. On-Campus MBA                         -0.013300
# Decided to Pursue MBA?                           -0.000797
# Salary Difference                                -0.525322
# Percent of Life Worked                           -0.023184
#
#                                 Has Management Experience  GRE/GMAT Score  \
# Person ID                                       -0.000675        0.021121
# Age                                              0.005230        0.002036
# Gender                                          -0.006506        0.003192
# Undergraduate Major                              0.006839        0.004822
# Undergraduate GPA                               -0.002126        0.013235
# Years of Work Experience                        -0.013501        0.015480
# Current Job Title                               -0.006897       -0.006611
# Annual Salary (Before MBA)                      -0.010309       -0.005471
# Has Management Experience                        1.000000       -0.000269
# GRE/GMAT Score                                  -0.000269        1.000000
# Undergrad University Ranking                     0.002537       -0.003357
# MBA Funding Source                              -0.015955        0.002817
# Desired Post-MBA Role                           -0.001734       -0.001206
# Expected Post-MBA Salary                        -0.010460        0.003743
# Location Preference (Post-MBA)                  -0.003523        0.017606
# Reason for MBA                                  -0.005699        0.010656
# Online vs. On-Campus MBA                         0.003065       -0.018841
# Decided to Pursue MBA?                          -0.006846       -0.002650
# Salary Difference                               -0.003316        0.006150
# Percent of Life Worked                          -0.015632        0.013412
#
#                                 Undergrad University Ranking  \
# Person ID                                           0.006243
# Age                                                -0.003281
# Gender                                             -0.015647
# Undergraduate Major                                 0.009238
# Undergraduate GPA                                   0.002768
# Years of Work Experience                            0.005455
# Current Job Title                                  -0.007176
# Annual Salary (Before MBA)                         -0.000487
# Has Management Experience                           0.002537
# GRE/GMAT Score                                     -0.003357
# Undergrad University Ranking                        1.000000
# MBA Funding Source                                  0.000089
# Desired Post-MBA Role                              -0.001833
# Expected Post-MBA Salary                            0.011014
# Location Preference (Post-MBA)                      0.001120
# Reason for MBA                                      0.003017
# Online vs. On-Campus MBA                           -0.005509
# Decided to Pursue MBA?                              0.005200
# Salary Difference                                   0.009637
# Percent of Life Worked                              0.006998
#
#                                 MBA Funding Source  Desired Post-MBA Role  \
# Person ID                                 0.008507               0.007743
# Age                                      -0.005496              -0.001699
# Gender                                   -0.008636               0.002167
# Undergraduate Major                       0.009498               0.004580
# Undergraduate GPA                        -0.005363               0.009183
# Years of Work Experience                 -0.002608               0.000922
# Current Job Title                        -0.002352              -0.004511
# Annual Salary (Before MBA)                0.011984              -0.013814
# Has Management Experience                -0.015955              -0.001734
# GRE/GMAT Score                            0.002817              -0.001206
# Undergrad University Ranking              0.000089              -0.001833
# MBA Funding Source                        1.000000               0.012406
# Desired Post-MBA Role                     0.012406               1.000000
# Expected Post-MBA Salary                 -0.000661               0.002912
# Location Preference (Post-MBA)            0.012273               0.010772
# Reason for MBA                           -0.008309              -0.000861
# Online vs. On-Campus MBA                 -0.016808              -0.004014
# Decided to Pursue MBA?                   -0.005506              -0.010639
# Salary Difference                        -0.007057               0.009964
# Percent of Life Worked                    0.001416               0.002708
#
#                                 Expected Post-MBA Salary  \
# Person ID                                       0.002500
# Age                                             0.016200
# Gender                                         -0.003292
# Undergraduate Major                             0.007340
# Undergraduate GPA                              -0.000869
# Years of Work Experience                       -0.002337
# Current Job Title                              -0.018362
# Annual Salary (Before MBA)                      0.019473
# Has Management Experience                      -0.010460
# GRE/GMAT Score                                  0.003743
# Undergrad University Ranking                    0.011014
# MBA Funding Source                             -0.000661
# Desired Post-MBA Role                           0.002912
# Expected Post-MBA Salary                        1.000000
# Location Preference (Post-MBA)                  0.002747
# Reason for MBA                                 -0.014038
# Online vs. On-Campus MBA                       -0.001918
# Decided to Pursue MBA?                          0.000723
# Salary Difference                               0.840512
# Percent of Life Worked                         -0.005728
#
#                                 Location Preference (Post-MBA)  \
# Person ID                                            -0.008117
# Age                                                   0.008160
# Gender                                                0.001608
# Undergraduate Major                                   0.004718
# Undergraduate GPA                                    -0.002364
# Years of Work Experience                             -0.007255
# Current Job Title                                     0.012410
# Annual Salary (Before MBA)                           -0.010305
# Has Management Experience                            -0.003523
# GRE/GMAT Score                                        0.017606
# Undergrad University Ranking                          0.001120
# MBA Funding Source                                    0.012273
# Desired Post-MBA Role                                 0.010772
# Expected Post-MBA Salary                              0.002747
# Location Preference (Post-MBA)                        1.000000
# Reason for MBA                                       -0.019008
# Online vs. On-Campus MBA                              0.003184
# Decided to Pursue MBA?                                0.018498
# Salary Difference                                     0.007922
# Percent of Life Worked                               -0.008586
#
#                                 Reason for MBA  Online vs. On-Campus MBA  \
# Person ID                            -0.002929                  0.007276
# Age                                  -0.002497                  0.015975
# Gender                                0.011413                  0.000172
# Undergraduate Major                   0.006429                  0.008558
# Undergraduate GPA                     0.000429                  0.001063
# Years of Work Experience             -0.013702                 -0.006023
# Current Job Title                     0.016909                  0.022142
# Annual Salary (Before MBA)            0.017700                 -0.013300
# Has Management Experience            -0.005699                  0.003065
# GRE/GMAT Score                        0.010656                 -0.018841
# Undergrad University Ranking          0.003017                 -0.005509
# MBA Funding Source                   -0.008309                 -0.016808
# Desired Post-MBA Role                -0.000861                 -0.004014
# Expected Post-MBA Salary             -0.014038                 -0.001918
# Location Preference (Post-MBA)       -0.019008                  0.003184
# Reason for MBA                        1.000000                 -0.005589
# Online vs. On-Campus MBA             -0.005589                  1.000000
# Decided to Pursue MBA?               -0.016128                 -0.000591
# Salary Difference                    -0.021538                  0.005575
# Percent of Life Worked               -0.016179                 -0.009711
#
#                                 Decided to Pursue MBA?  Salary Difference  \
# Person ID                                     0.001799           0.001241
# Age                                           0.000614           0.007617
# Gender                                       -0.001175           0.003999
# Undergraduate Major                           0.000688           0.012453
# Undergraduate GPA                            -0.008400          -0.002003
# Years of Work Experience                     -0.005571           0.009962
# Current Job Title                            -0.005370          -0.015170
# Annual Salary (Before MBA)                   -0.000797          -0.525322
# Has Management Experience                    -0.006846          -0.003316
# GRE/GMAT Score                               -0.002650           0.006150
# Undergrad University Ranking                  0.005200           0.009637
# MBA Funding Source                           -0.005506          -0.007057
# Desired Post-MBA Role                        -0.010639           0.009964
# Expected Post-MBA Salary                      0.000723           0.840512
# Location Preference (Post-MBA)                0.018498           0.007922
# Reason for MBA                               -0.016128          -0.021538
# Online vs. On-Campus MBA                     -0.000591           0.005575
# Decided to Pursue MBA?                        1.000000           0.001047
# Salary Difference                             0.001047           1.000000
# Percent of Life Worked                       -0.005731           0.007688
#
#                                 Percent of Life Worked
# Person ID                                    -0.000807
# Age                                          -0.226782
# Gender                                       -0.005961
# Undergraduate Major                          -0.000266
# Undergraduate GPA                            -0.013489
# Years of Work Experience                      0.962833
# Current Job Title                            -0.018081
# Annual Salary (Before MBA)                   -0.023184
# Has Management Experience                    -0.015632
# GRE/GMAT Score                                0.013412
# Undergrad University Ranking                  0.006998
# MBA Funding Source                            0.001416
# Desired Post-MBA Role                         0.002708
# Expected Post-MBA Salary                     -0.005728
# Location Preference (Post-MBA)               -0.008586
# Reason for MBA                               -0.016179
# Online vs. On-Campus MBA                     -0.009711
# Decided to Pursue MBA?                       -0.005731
# Salary Difference                             0.007688
# Percent of Life Worked                        1.000000

# %%
#4. Modeling

#Linear Regression Modeling
lr = linear_model.LinearRegression()
fit = lr.fit(data_train_ftrs, data_train_tgt)
preds = lr.predict(data_train_ftrs)

mse = mean_squared_error(data_train_tgt, preds)

#Mean Squared Error for evaluation of model
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
# Out:
# MSE:  0.24193221142858715
# RMSE:  0.49186605029071395

# %%
#5. Model Evaluation

#Creation of Linear Regression and KNN models
lrknn = [linear_model.LinearRegression(),
              neighbors.KNeighborsRegressor(n_neighbors=3),
              neighbors.KNeighborsRegressor(n_neighbors=10)]

#Creation of Lasso and Ridge models
penalized_lr = [linear_model.Lasso(),
                linear_model.Ridge()]

#Creation of SVR models
svrs = [svm.SVR(), svm.NuSVR()]

#Decision Tree Regressor models
dtrees = [tree.DecisionTreeRegressor(max_depth=md) for md in [1, 3, 5, 10]]

#Comibining all models
reg_models = lrknn + penalized_lr + svrs + dtrees

#RMS_Error function
def rms_error(actual, predicted):
  ' root-mean-squared-error function ' #lesser values are better (a<b means a is better)
  mse = metrics.mean_squared_error(actual, predicted)
  return np.sqrt(mse)
rms_scorer = metrics.make_scorer(rms_error)

scaler = StandardScaler()

def rms_error(actual, predicted):
  return np.sqrt(mean_squared_error(actual, predicted))

errors = {}
for model in reg_models:
    pipe = pipeline.make_pipeline(scaler, model)
    preds = skms.cross_val_predict(pipe,
                                   data_train_ftrs, data_train_tgt,
                                   cv=10)
    key = (model.__class__.__name__ +
           str(model.get_params().get('max_depth', "")) +
           str(model.get_params().get('n_neighbors', "")))
    errors[key] = rms_error(data_train_tgt, preds)

#Displaying RMSE
df = pd.DataFrame.from_dict(errors, orient='index').sort_values(0)
df.columns=['RMSE']
display(df)
# Out:
#                              RMSE
# Lasso                    0.492336
# Ridge                    0.493100
# LinearRegression         0.493101
# DecisionTreeRegressor1   0.493243
# DecisionTreeRegressor3   0.495380
# NuSVR                    0.499193
# DecisionTreeRegressor5   0.500006
# KNeighborsRegressor10    0.514723
# DecisionTreeRegressor10  0.536262
# SVR                      0.547929
# KNeighborsRegressor3     0.567618

# %%
def rms_error(actual, predicted):
  return np.sqrt(mean_squared_error(actual, predicted))

rms_scorer = make_scorer(rms_error)

#Top performing models for further evaluation
better_models = [linear_model.Lasso(),
                 linear_model.Ridge(),
                 linear_model.LinearRegression(),
                 tree.DecisionTreeRegressor(max_depth=1),
                 tree.DecisionTreeRegressor(max_depth=3)]

#Line plot of RMSE and CV-Fold
fig, ax = plt.subplots(1, 1, figsize=(8,4))
for model in better_models:
    pipe = pipeline.make_pipeline(scaler, model)
    cv_results = skms.cross_val_score(pipe,
                                      data_train_ftrs, data_train_tgt,
                                      scoring = rms_scorer,
                                      cv=10)

    my_lbl = "{:s} ({:5.3f}$\pm${:.2f})".format(model.__class__.__name__,
                                                cv_results.mean(),
                                                cv_results.std())
    ax.plot(cv_results, 'o--', label=my_lbl)
    ax.set_xlabel('CV-Fold #')
    ax.set_ylabel("RMSE")
    ax.legend()

# %%
# Classification model

# Initialize and train a RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(data_train_ftrs, data_train_tgt)

rf_predictions = rf_classifier.predict(data_test_ftrs)

# Model accuracy
print(classification_report(data_test_tgt, rf_predictions))
print("Accuracy:", accuracy_score(data_test_tgt, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.16      0.23      1205
#            1       0.60      0.84      0.70      1795
#
#     accuracy                           0.57      3000
#    macro avg       0.50      0.50      0.46      3000
# weighted avg       0.52      0.57      0.51      3000
#
# Accuracy: 0.569

# %%
#Initialize and train a RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(data_train_ftrs, data_train_tgt)

#Test predictions
rf_predictions = rf_classifier.predict(data_test_ftrs)

# Get feature importances
feature_importances = rf_classifier.feature_importances_

# Drop 'Person ID'
mask = data_train_ftrs.columns != 'Person ID'
filtered_columns = data_train_ftrs.columns[mask]
filtered_importances = feature_importances[mask]

# Create DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': filtered_columns,
    'Importance': filtered_importances
})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the feature importances
feature_importance_df
# Out:
#                            Feature  Importance
# 9     Undergrad University Ranking    0.098983
# 12        Expected Post-MBA Salary    0.098890
# 8                   GRE/GMAT Score    0.098879
# 6       Annual Salary (Before MBA)    0.098585
# 16               Salary Difference    0.097551
# 3                Undergraduate GPA    0.096548
# 17          Percent of Life Worked    0.076248
# 0                              Age    0.059472
# 4         Years of Work Experience    0.039600
# 1                           Gender    0.019715
# 7        Has Management Experience    0.015313
# 14                  Reason for MBA    0.015185
# 10              MBA Funding Source    0.015185
# 15        Online vs. On-Campus MBA    0.015025
# 13  Location Preference (Post-MBA)    0.014750
# 2              Undergraduate Major    0.014145
# 11           Desired Post-MBA Role    0.013128
# 5                Current Job Title    0.012595

# %%
#KNN Set-Up
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
fit = knn.fit(data_train_ftrs, data_train_tgt)

#3 Nearest Neighbors (3NN) accuracy prediction
predictions = fit.predict(data_test_ftrs)
print("3NN Accuracy:", metrics.accuracy_score(data_test_tgt, predictions))

#KNN Classifier for 3NN
models = {'kNN': neighbors.KNeighborsClassifier(n_neighbors=3)}

# Prediction Accuracy Score
for name, model in models.items():
    fit = model.fit(data_train_ftrs, data_train_tgt)
    predictions = fit.predict(data_test_ftrs)
    score = metrics.accuracy_score(data_test_tgt, predictions)
    print("{:>3s}: {:0.2f}".format(name, score))

#Time to run KNN
start_time = time.time()
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
fit = knn.fit(data_train_ftrs, data_train_tgt)
preds = knn.predict(data_test_ftrs)
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Prediction time for k-NN: {elapsed_time:.2f} seconds")
# Out:
# 3NN Accuracy: 0.5096666666666667
# kNN: 0.51
# Prediction time for k-NN: 0.22 seconds

# %%
#KNN Accuracy
tgt_preds = (neighbors.KNeighborsClassifier()
                      .fit(data_train_ftrs, data_train_tgt)
                      .predict(data_test_ftrs))

print("accuracy:", metrics.accuracy_score(data_test_tgt,
                                          tgt_preds))

# KNN Confusion Matrix
cm = metrics.confusion_matrix(data_test_tgt,
                              tgt_preds)
print("confusion matrix:", cm, sep="\n")
# Out:
# accuracy: 0.53
# confusion matrix:
# [[ 401  804]
#  [ 606 1189]]

# %%
#Classification Model
print(metrics.classification_report(data_test_tgt,
                                    tgt_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.33      0.36      1205
#            1       0.60      0.66      0.63      1795
#
#     accuracy                           0.53      3000
#    macro avg       0.50      0.50      0.50      3000
# weighted avg       0.52      0.53      0.52      3000

# %%
# Visual - Cross-Val Score

#Baseline accuracy to test against
baseline = dummy.DummyClassifier(strategy="most_frequent")
baseline.fit(data_train_ftrs, data_train_tgt)
base_preds = baseline.predict(data_test_ftrs)
base_acc = metrics.accuracy_score(base_preds, data_test_tgt)
print("Baseline accuracy: ", base_acc)

#Creation of necessary classifiers
classifiers = {'base'  : baseline,
               'logreg': linear_model.LogisticRegression(solver='lbfgs', max_iter=10000),
               '3-NN'  : neighbors.KNeighborsClassifier(n_neighbors=3),
               '10-NN' : neighbors.KNeighborsClassifier(n_neighbors=10)}

#Measures plotted
msrs = ['accuracy', 'average_precision', 'recall', 'f1']

#Format the graphs
fig, axes = plt.subplots(len(msrs), 1, figsize=(6, 2*len(msrs)))
fig.tight_layout()

#Cross Validation Score
for mod_name, model in classifiers.items():
    cvs = skms.cross_val_score
    cv_results = {msr:cvs(model, data_test_ftrs, data_test_tgt,
                          scoring=msr, cv=10) for msr in msrs}

#Graph set-up
    for ax, msr in zip(axes, msrs):
        msr_results = cv_results[msr]
        my_lbl = "{:12s} {:.3f} {:.2f}".format(mod_name,
                                               msr_results.mean(),
                                               msr_results.std())
        ax.plot(msr_results, 'o--', label=my_lbl)
        ax.set_title(msr)
        ax.legend(loc='lower center', ncol=2)
# Out:
# Baseline accuracy:  0.5983333333333334

# %%
# Visual - Cross-Val Predict Confusion Matrix

#Graph Layout Set-Up
fig, axes = plt.subplots(2,2, figsize=(4,4), sharex=True, sharey=True)
fig.tight_layout()

#Cross Validation Prediction
for ax, (mod_name, model) in zip(axes.flat, classifiers.items()):
    preds = skms.cross_val_predict(model,
                                   data_test_ftrs, data_test_tgt,
                                   cv=10)
    # Confusion Matrix
    cm = metrics.confusion_matrix(data_test_tgt, preds)
    sns.heatmap(cm, annot=True, ax=ax,
                cbar=False, square=True, fmt="d")

    ax.set_title(mod_name)

axes[1,0].set_xlabel('Predicted')
axes[1,1].set_xlabel('Predicted')
axes[0,0].set_ylabel('Actual')
axes[1,0].set_ylabel('Actual');

# %%
# Actual vs Predicted Confusion Matrix

#Heatmap of Predicted and Actual
fig, ax = plt.subplots(1,1,figsize=(4,4))
cm = metrics.confusion_matrix(data_test_tgt, tgt_preds)
ax = sns.heatmap(cm, annot=True, square=True, fmt="d")
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual');

print("Dataset shape:", df.shape)
print("\nTarget column value counts:\n", data_train_tgt.value_counts())
# Out:
# Dataset shape: (11, 1)
#
# Target column value counts:
#  Decided to Pursue MBA?
# 1    4112
# 0    2888
# Name: count, dtype: int64
